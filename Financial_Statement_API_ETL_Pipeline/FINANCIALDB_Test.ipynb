# %%
# %load_ext sql

# %%
# %sql dialect+driver://username:password@host:port/database
# %sql postgresql://postgres:iEchu133@localhost/financialdb

# %%
# %sql SELECT * FROM companies LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/financialdb
# 2 rows affected.
# [(1, 66740, '3M', 'MMM'), (0, 91142, 'A. O. Smith', 'AOS')]

# %%
# %sql SELECT * FROM company_financials LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/financialdb
# 10 rows affected.
# [(1, 35355000000, 1, 75, 0, 8),
#  (2, 32184000000, 1, 75, 0, 6),
#  (3, 32136000000, 1, 75, 0, 4),
#  (4, 32765000000, 1, 75, 0, 2),
#  (5, 31657000000, 1, 75, 0, 0),
#  (6, 3538900000, 0, 75, 0, 9),
#  (7, 2895300000, 0, 75, 0, 7),
#  (8, 2992700000, 0, 75, 0, 5),
#  (9, 3187900000, 0, 75, 0, 3),
#  (10, 2996700000, 0, 75, 0, 1)]

# %%
# %sql SELECT * FROM financial_statements;
# Out:
#  * postgresql://postgres:***@localhost/financialdb
# 3 rows affected.
# [(0, 'Balance Sheet'), (2, 'Income Statement'), (1, 'Cash-Flow Statement')]

# %%
# %sql SELECT * FROM financial_accounts LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/financialdb
# 10 rows affected.
# [(75, 'Revenue'),
#  (16, 'Cost Of Revenue'),
#  (33, 'Gross Profit'),
#  (34, 'Gross Profit Ratio'),
#  (73, 'Research And Development Expenses'),
#  (30, 'General And Administrative Expenses'),
#  (77, 'Selling And Marketing Expenses'),
#  (78, 'Selling General And Administrative Expenses'),
#  (61, 'Other Expenses'),
#  (55, 'Operating Expenses')]

# %%
# %sql SELECT * FROM time LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/financialdb
# 10 rows affected.
# [(8, datetime.date(2021, 12, 31), datetime.date(2022, 2, 9), datetime.datetime(2022, 2, 9, 15, 13, 29), 2021),
#  (6, datetime.date(2020, 12, 31), datetime.date(2021, 2, 4), datetime.datetime(2021, 2, 4, 13, 53, 11), 2020),
#  (4, datetime.date(2019, 12, 31), datetime.date(2020, 2, 6), datetime.datetime(2020, 2, 6, 16, 16, 31), 2019),
#  (2, datetime.date(2018, 12, 31), datetime.date(2019, 2, 7), datetime.datetime(2019, 2, 7, 17, 15, 37), 2018),
#  (0, datetime.date(2017, 12, 31), datetime.date(2018, 2, 8), datetime.datetime(2018, 2, 8, 17, 14, 52), 2017),
#  (9, datetime.date(2021, 12, 31), datetime.date(2022, 2, 11), datetime.datetime(2022, 2, 11, 14, 19, 32), 2021),
#  (7, datetime.date(2020, 12, 31), datetime.date(2021, 2, 12), datetime.datetime(2021, 2, 12, 12, 27, 8), 2020),
#  (5, datetime.date(2019, 12, 31), datetime.date(2020, 2, 24), datetime.datetime(2020, 2, 24, 17, 31, 6), 2019),
# ...

# %%
# %sql SELECT * FROM financial_statement_view LIMIT 10 ;
# Out:
#  * postgresql://postgres:***@localhost/financialdb
# 10 rows affected.
# [(66740, '3M', 'MMM', 'Revenue', 'Balance Sheet', datetime.date(2021, 12, 31), datetime.date(2022, 2, 9), datetime.datetime(2022, 2, 9, 15, 13, 29), 2021, 35355000000),
#  (66740, '3M', 'MMM', 'Revenue', 'Balance Sheet', datetime.date(2020, 12, 31), datetime.date(2021, 2, 4), datetime.datetime(2021, 2, 4, 13, 53, 11), 2020, 32184000000),
#  (66740, '3M', 'MMM', 'Revenue', 'Balance Sheet', datetime.date(2019, 12, 31), datetime.date(2020, 2, 6), datetime.datetime(2020, 2, 6, 16, 16, 31), 2019, 32136000000),
#  (66740, '3M', 'MMM', 'Revenue', 'Balance Sheet', datetime.date(2018, 12, 31), datetime.date(2019, 2, 7), datetime.datetime(2019, 2, 7, 17, 15, 37), 2018, 32765000000),
#  (66740, '3M', 'MMM', 'Revenue', 'Balance Sheet', datetime.date(2017, 12, 31), datetime.date(2018, 2, 8), datetime.datetime(2018, 2, 8, 17, 14, 52), 2017, 31657000000),
# ...
