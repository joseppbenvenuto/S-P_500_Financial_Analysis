# %%
# %load_ext sql

# %%
# %sql dialect+driver://username:password@host:port/database
# %sql postgresql://postgres:iEchu133@localhost/yahoodb

# %%
# %sql SELECT * FROM companies LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/edgardb
# 10 rows affected.
# [(1800, 'ABBOTT LABORATORIES', 'ABT'),
#  (1961, 'WORLDS INC.', 'WDDD'),
#  (2034, 'ACETO CORP', 'NaN'),
#  (2098, 'ACME UNITED CORP', 'ACU'),
#  (2186, 'BK TECHNOLOGIES CORPORATION', 'BKTI'),
#  (2488, 'ADVANCED MICRO DEVICES, INC', 'AMD'),
#  (2491, 'BALLY TECHNOLOGIES, INC.', 'NaN'),
#  (2969, 'AIR PRODUCTS AND CHEMICALS, INC.', 'APD'),
#  (3116, 'AKORN INC', 'NaN'),
#  (3197, 'CECO ENVIRONMENTAL CORP.', 'CECE')]

# %%
# %sql SELECT * FROM company_financials LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/edgardb
# 10 rows affected.
# [(1, 1750, '2011-05-31', 185096000.0, '0001047469-11-006302', '2011', 'FY', '10-K', '2011-07-13', '', 'Accounts Payable Current', "Carrying value as of the balance sheet date of liabilities incurred (and for which invoices have typically been received) and payable to vendors for  ... (42 characters truncated) ... in an entity's business. Used to reflect the current portion of the liabilities (due within one year or within the normal operating cycle if longer)."),
# ...

# %%
# %sql SELECT * FROM edgar_view LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/edgardb
# 10 rows affected.
# [(1750, 'AAR CORP', 'AIR', '2012-05-31', '0001047469-12-007300', 'FY', '10-K', '2012-07-19', '', 201405000.0, '2012', 'Accounts Payable Current', "Carrying value as of the balance sheet date of liabilities incurred (and for which invoices have typically been received) and payable to vendors for  ... (42 characters truncated) ... in an entity's business. Used to reflect the current portion of the liabilities (due within one year or within the normal operating cycle if longer)."),
# ...
